# %%
import pandas as pd

# %%
df_new = pd.read_csv('datas.csv')

# %%
df_new['memory'] = df_new['memory'].apply(eval)

# %%
df_new.reset_index(inplace=True)
df_new.rename(columns={'index':'id'}, inplace=True)

# %%
df_new['id'] = df_new['id'] + 1

# %%
length = list()
width = list()
thinckness = list()
for row in df_new['dimensions'].str.split(' x '):
    length.append(row[0])
    width.append(row[1])
    thinckness.append(row[2].strip())

# %%
df_new['length'] = length
df_new['width'] = width
df_new['thinckness'] = thinckness

# %%
length_resolution = list()
width_resolution = list()
for row in df_new['resolution'].str.split(' x '):
    length_resolution.append(row[0])
    width_resolution.append(row[1].strip())

# %%
df_new['length_resolution'] = length_resolution
df_new['width_resolution'] = width_resolution

# %%
df_new.loc[df_new['type'] == 'iPadOS', 'type'] = 'iOS'

# %%
df_new['type'].unique()
# Out:
# array(['Android', 'other', 'iOS'], dtype=object)

# %%
os = list()
for row in df_new[['type', 'version']].values:
   os.append((row[0],row[1]))

# %%
os = set(os)

# %%
os_id = list()
for row in df_new[['type', 'version']].values:
    for i, val in enumerate(os):
        if val == ((row[0], row[1])):
            os_id.append(i + 1)

# %%
df_new['os_id'] = os_id

# %%
df_new[['os_id', 'type', 'version', ]]
# Out:
#       os_id     type version
# 0        39  Android      10
# 1        39  Android      10
# 2        39  Android      10
# 3        39  Android      10
# 4        39  Android      10
# ...     ...      ...     ...
# 2646      6  Android   5.0.2
# 2647     14  Android     5.1
# 2648     14  Android     5.1
# 2649      6  Android   5.0.2
# 2650     69  Android   5.1.1
#
# [2651 rows x 3 columns]

# %%
brand = list()
for row in df_new['brand']:
    brand.append(row)

# %%
brand
# Out:
# ['Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
#  'Huawei',
# ...

# %%
brand = set(brand)

# %%
brand_id = list()
for row in df_new['brand']:
    for i, val in enumerate(brand):
        if val == row:
            brand_id.append(i + 1)

# %%
brand_id
# Out:
# [7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
#  7,
# ...

# %%
df_new['brand_id'] = brand_id

# %%
phone = df_new[['id', 'brand_id', 'name', 'year', 'price', 'battery', 'network', 'os_id', 'weight', 'sim', 'size', 'length_resolution', 'width_resolution', 'ppi_density', 'screen_to_body_ratio', 'length', 'width', 'thinckness']]

# %%
phone.head()
# Out:
#    id  brand_id              name  year  price  battery  network  os_id  \
# 0   1         7               Y9a  2020  200.0   4200.0      111     39
# 1   2         7  Enjoy 20 Plus 5G  2020  280.0   4200.0      111     39
# 2   3         7       Enjoy 20 5G  2020  210.0   5000.0      111     39
# 3   4         7      MatePad 10.8  2020  300.0   7500.0      111     39
# 4   5         7     MatePad T 10s  2020  200.0   5100.0      111     39
#
#    weight       sim   size length_resolution width_resolution  ppi_density  \
# 0   197.0  Nano-SIM   6.63              1080             2400        397.0
# 1   197.0  Nano-SIM   6.63              1080             2400        397.0
# 2   188.0  Nano-SIM   6.60               720             1600        266.0
# 3   500.0  Nano-SIM  10.80              1600             2560        280.0
# 4   450.0  Nano-SIM  10.10              1200             1920        224.0
#
#    screen_to_body_ratio length width thinckness
# ...

# %%
brand_with_id = list()
for row in df_new[['brand_id', 'brand']].values:
    brand_with_id.append((row[0], row[1]))

# %%
brand_with_id = set(brand_with_id)

# %%
brand = pd.DataFrame(brand_with_id)
brand = brand.rename(columns={0:'id', 1:'name'})
brand
# Out:
#     id     name
# 0    7   Huawei
# 1    1     Sony
# 2    3    Apple
# 3    4  Infinix
# 4    2  alcatel
# 5   13      BLU
# 6   11  Samsung
# 7   14     Asus
# 8   12   Lenovo
# 9    9   Xiaomi
# 10   6      HTC
# 11   8    Nokia
# 12   5       LG
# 13  10      ZTE

# %%
os_with_id = list()
for row in df_new[['os_id', 'type', 'version']].values:
    os_with_id.append((row[0], row[1], row[2]))

# %%
os_with_id = set(os_with_id)

# %%
os = pd.DataFrame(os_with_id)
os.rename(columns={0:'id', 1:'type', 2:'version'}, inplace=True)
os
# Out:
#     id     type version
# 0   79  Android   4.2.1
# 1   53  Android   7.1.1
# 2   26  Android     3.0
# 3   52      iOS    16.1
# 4   51  Android     5.2
# ..  ..      ...     ...
# 77  28  Android     2.3
# 78  59      iOS      13
# 79   7      iOS    15.4
# 80  31      iOS    11.3
# 81  39  Android      10
#
# [82 rows x 3 columns]

# %%
df_new['sensor'] = df_new['sensor'].apply(eval)

# %%
sensor_list = list()
for row in df_new['sensor'].values:
    for i in row:
        sensor_list.append(i)

# %%
sensor_set = set(sensor_list)

# %%
sensor_with_id = list()
for row in df_new['sensor']:
    new_list = list()
    for val in row:
        for i, sens in enumerate(sensor_set):
            if val == sens:
                new_list.append((i + 1, val))
    sensor_with_id.append(new_list)

# %%
sensor_with_id
# Out:
# [[(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(9, 'Accelerometer'), (3, 'proximity')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (3, 'proximity'),
#   (22, 'compass')],
#  [(25, 'Fingerprint'),
#   (26, 'accelerometer'),
#   (5, 'gyro'),
#   (3, 'proximity'),
# ...

# %%
df_new['sensor_with_id'] = sensor_with_id

# %%
df_new[['id', 'sensor_with_id']]
# Out:
#         id                                     sensor_with_id
# 0        1  [(25, Fingerprint), (26, accelerometer), (5, g...
# 1        2  [(25, Fingerprint), (26, accelerometer), (5, g...
# 2        3  [(25, Fingerprint), (26, accelerometer), (3, p...
# 3        4  [(25, Fingerprint), (26, accelerometer), (5, g...
# 4        5               [(9, Accelerometer), (3, proximity)]
# ...    ...                                                ...
# 2646  2647  [(25, Fingerprint), (26, accelerometer), (5, g...
# 2647  2648                                        [(18, Yes)]
# 2648  2649               [(9, Accelerometer), (3, proximity)]
# 2649  2650  [(9, Accelerometer), (3, proximity), (22, comp...
# 2650  2651  [(9, Accelerometer), (5, gyro), (3, proximity)...
#
# [2651 rows x 2 columns]

# %%
phone_sensor = list()
for row in df_new[['id', 'sensor_with_id']].values:
    for val in row[1]:
        phone_sensor.append((row[0],val[0]))

# %%
phone_sensor = pd.DataFrame(phone_sensor)
phone_sensor.rename(columns={0:'phone_id', 1:'sensor_id'}, inplace=True)
phone_sensor.head()
# Out:
#    phone_id  sensor_id
# 0         1         25
# 1         1         26
# 2         1          5
# 3         1          3
# 4         1         22

# %%
sensor = list()
for row in sensor_with_id:
    for val in row:
        sensor.append(val)

# %%
sensor = set(sensor)

# %%
sensor = pd.DataFrame(sensor)
sensor.rename(columns={0:'id', 1:'name'}, inplace=True)
sensor.head()
# Out:
#    id                  name
# 0  26         accelerometer
# 1  33             barometer
# 2   5                  gyro
# 3  31      Face recognition
# 4  24  ultrasound proximity

# %%
memories = list()
for row in df_new['memory']:
    for val in row:
        memories.append(val)

# %%
memories = set(memories)

# %%
mem_with_id = list()
for row in df_new['memory']:
    new_list = list()
    for val in row:
        for i, mem in enumerate(memories):
            if mem == val:
                new_list.append((i+1, mem))
    mem_with_id.append(new_list)

# %%
for row in df_new['memory']:
    print(row)
# Out:
# [('128', '6'), ('128', '8')]
# [('128', '6'), ('128', '8')]
# [('64', '4'), ('128', '4'), ('128', '6')]
# [('64', '6'), ('128', '6'), ('256', '6')]
# [('16', '2'), ('32', '2'), ('64', '3'), ('64', '4'), ('128', '4')]
# [('128', '6'), ('128', '8')]
# [('64', '6'), ('128', '6'), ('128', '8')]
# [('128', '4')]
# [('128', '4'), ('128', '6')]
# [('128', '6'), ('128', '8')]
# [('128', '6'), ('256', '8')]
# [('16', '2'), ('32', '2'), ('32', '3')]
# [('64', '4'), ('128', '4')]
# [('32', '3'), ('64', '3'), ('64', '4')]
# [('32', '2')]
# [('128', '4')]
# [('128', '8'), ('256', '8')]
# [('128', '8'), ('256', '8')]
# [('128', '6'), ('128', '8'), ('256', '8')]
# [('32', '3'), ('64', '4'), ('128', '4'), ('128', '6')]
# [('64', '4'), ('128', '4')]
# [('256', '8'), ('512', '8')]
# [('128', '8'), ('256', '8'), ('512', '8')]
# [('128', '6'), ('128', '8'), ('256', '8')]
# [('64', '4')]
# [('128', '6'), ('128', '8')]
# [('128', '6'), ('256', '8'), ('512', '8')]
# [('512', '8')]
# ...

# %%
df_new['mem_with_id'] = mem_with_id

# %%
phone_memory = list()
for row in df_new[['id', 'mem_with_id']].values:
    for val in row[1]:
        phone_memory.append((row[0], val[0]))

# %%
phone_memory = pd.DataFrame(phone_memory)
phone_memory.rename(columns={0:'phone_id', 1:'memory_id'}, inplace=True)

# %%
phone_memory
# Out:
#       phone_id  memory_id
# 0            1         27
# 1            1         76
# 2            2         27
# 3            2         76
# 4            3         55
# ...        ...        ...
# 4849      2648         69
# 4850      2649         17
# 4851      2650         69
# 4852      2651         33
# 4853      2651         55
#
# [4854 rows x 2 columns]

# %%
memory = list()
for row in df_new['mem_with_id'].values:
    for val in row:
        memory.append((val[0], val[1][0], val[1][1]))

# %%
memory = set(memory)

# %%
memory = pd.DataFrame(memory)
memory.rename(columns={0:'id', 1:'main_memory', 2:'ram'}, inplace=True)
memory.head()
# Out:
#    id main_memory  ram
# 0  26           1   12
# 1  78          16  640
# 2  38           4  384
# 3  12           2   16
# 4  22          64    3

# %%
phone.rename(columns={'name':'model', 'ppi_density':'ppi', 'screen_to_body_ratio':'ratio'}, inplace=True)
phone.head()
# Out:
# C:\Users\parsa\AppData\Local\Temp\ipykernel_16016\1642023911.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phone.rename(columns={'name':'model', 'ppi_density':'ppi', 'screen_to_body_ratio':'ratio'}, inplace=True)
#    id  brand_id             model  year  price  battery  network  os_id  \
# 0   1         7               Y9a  2020  200.0   4200.0      111     39
# 1   2         7  Enjoy 20 Plus 5G  2020  280.0   4200.0      111     39
# 2   3         7       Enjoy 20 5G  2020  210.0   5000.0      111     39
# 3   4         7      MatePad 10.8  2020  300.0   7500.0      111     39
# 4   5         7     MatePad T 10s  2020  200.0   5100.0      111     39
#
#    weight       sim   size length_resolution width_resolution    ppi  ratio  \
# ...

# %%
phone.to_csv('db_datas/phone.csv', index=False)
os.to_csv('db_datas/os.csv', index=False)
brand.to_csv('db_datas/brand.csv', index=False)
phone_sensor.to_csv('db_datas/phone-sensor.csv', index=False)
sensor.to_csv('db_datas/sensor.csv', index=False)
phone_memory.to_csv('db_datas/phone-memory.csv', index=False)
memory.to_csv('db_datas/memory.csv', index=False)
df_new.to_csv('db_datas/preprocesing_datas.csv', index=False)

# %%
 import pandas as pd

# %%
df = pd.read_csv('preprocesing_datas.csv')

# %%
df['core']
# Out:
# 0       8.0
# 1       8.0
# 2       8.0
# 3       8.0
# 4       8.0
#        ...
# 2646    8.0
# 2647    4.0
# 2648    4.0
# 2649    4.0
# 2650    8.0
# Name: core, Length: 2651, dtype: float64

# %%
phone = pd.read_csv('phone.csv')

# %%
phone['core'] = df['core']

# %%
phone
# Out:
#         id  brand_id             model  year  price  battery  os_id  weight  \
# 0        1         7               Y9a  2020  200.0   4200.0     39   197.0
# 1        2         7  Enjoy 20 Plus 5G  2020  280.0   4200.0     39   197.0
# 2        3         7       Enjoy 20 5G  2020  210.0   5000.0     39   188.0
# 3        4         7      MatePad 10.8  2020  300.0   7500.0     39   500.0
# 4        5         7     MatePad T 10s  2020  200.0   5100.0     39   450.0
# ...    ...       ...               ...   ...    ...      ...    ...     ...
# 2646  2647        10          Axon Lux  2015  300.0   3000.0      6   168.0
# 2647  2648        10        Boost Max+  2015  180.0   3400.0     14   194.8
# 2648  2649        10        Blade A460  2015  100.0   2200.0     14   198.0
# 2649  2650        10          Blade D6  2015  100.0   2200.0      6   122.0
# 2650  2651        10          Axon Pro  2015  290.0   3000.0     69   172.9
#
# ...

# %%
phone.to_csv('phone.csv', index=False)
